# %% [markdown]
# # MLB 球員下一年薪資預測專案

# %% [markdown]
# # 專案目標與商業意義
# - 目標：用 t 年表現預測 t+1 年薪資（log 轉換）
# - 意義：幫助球團評估合約價值、仲裁預測、自由市場參考

# %% [markdown]
# # 基礎環境設定

# %%
import pandas as pd
import numpy as np
from pybaseball import batting_stats, pitching_stats, lahman
import os
import matplotlib.pyplot as plt
import matplotlib.font_manager as fm
plt.rcParams['font.sans-serif'] = ['Microsoft JhengHei']


# 姓名清洗函數 方便合併
def clean_name(name): 
    if isinstance(name, str):
        return name.lower().replace(" ", "").replace(".", "").replace("'", "")
    return ""

# %% [markdown]
# # 原始數據抓取

# %%
# 抓取打者數據
B_RAW_DATA_FILE = 'data/mlb_raw_batting_2013_2023.csv'

if not os.path.exists(B_RAW_DATA_FILE):
    print("正在抓取打者原始數據 (2013-2023)...")
    b_raw_stats = batting_stats(2013, 2023, split_seasons=True)
    b_raw_stats.to_csv(B_RAW_DATA_FILE, index=False)
    print(f"原始數據已儲存至 {B_RAW_DATA_FILE}")
else:
    b_raw_stats = pd.read_csv(B_RAW_DATA_FILE)
    print("已從本地讀取打者原始數據。")

b_raw_stats['name_clean'] = b_raw_stats['Name'].apply(clean_name)

# 抓取投手數據
P_RAW_DATA_FILE = 'data/mlb_raw_pitching_2013_2023.csv'

if not os.path.exists(P_RAW_DATA_FILE):
    print("正在抓取投手原始數據 (2013-2023)...")
    p_raw_stats = pitching_stats(2013, 2023, split_seasons=True)
    p_raw_stats.to_csv(P_RAW_DATA_FILE, index=False)
    print(f"原始數據已儲存至 {P_RAW_DATA_FILE}")
else:
    p_raw_stats = pd.read_csv(P_RAW_DATA_FILE)
    print("已從本地讀取投手原始數據。")

p_raw_stats['name_clean'] = p_raw_stats['Name'].apply(clean_name)


# 讀取薪資數據 (https://www.kaggle.com/datasets/christophertreasure/mlb-player-salaries-2011-2024)
salary_df = pd.read_csv('data/mlb_salary_data.csv', encoding='latin1')
print("已從本地讀取薪資原始數據。")

salary_df ['name_clean'] = salary_df ['Name'].apply(clean_name)

# 讀取年資數據 (https://www.kaggle.com/datasets/dalyas/lahman-baseball-database/data)
people_path = 'data/People.csv'
people = pd.read_csv(people_path)
print("已從本地讀取年資原始數據。")

people['name_clean'] = (people['nameFirst'] + people['nameLast']).apply(clean_name)
# Out:
# 已從本地讀取打者原始數據。
# 已從本地讀取投手原始數據。
# 已從本地讀取薪資原始數據。
# 已從本地讀取年資原始數據。

# %% [markdown]
# # 資料合併

# %%
# 處理薪資表：產生「下一年薪資」視角
salary_df = salary_df.sort_values(['name_clean', 'Year'])

# 處理薪資符號
salary_df['Salary'] = salary_df['Salary'].replace({r'[\$,]': ''}, regex=True).astype(float)

# 在薪資表中產生下一年薪資（用來合併）
salary_df['next_year_salary'] = salary_df.groupby('name_clean')['Salary'].shift(-1)
salary_df['next_year_log_salary'] = np.log1p(salary_df['next_year_salary'])

# 計算 debut year
people['debut'] = pd.to_datetime(people['debut'], errors='coerce')
people['debut_year'] = people['debut'].dt.year.fillna(0).astype(int)

# 合併薪資 (left join，用 name_clean + Year)
batting_df = b_raw_stats.merge(
    salary_df[['name_clean', 'Year', 'Team', 'Salary', 'Name', 'next_year_salary', 'next_year_log_salary']],
    left_on=['name_clean', 'Season'],
    right_on=['name_clean', 'Year'],
    how='left',
    suffixes=('', '_sal')
)

pitching_df = p_raw_stats.merge(
    salary_df[['name_clean', 'Year', 'Team', 'Salary', 'Name', 'next_year_salary', 'next_year_log_salary']],
    left_on=['name_clean', 'Season'],
    right_on=['name_clean', 'Year'],
    how='left',
    suffixes=('', '_sal')
)

# 合併 debut_year
people_subset = people[['name_clean', 'debut_year']].drop_duplicates()
batting_df = batting_df.merge(
    people_subset,
    on='name_clean',
    how='left'
)

pitching_df = pitching_df.merge(
    people_subset,
    on='name_clean',
    how='left'
)

# 計算「當季結束時的服務年資」（這是用來決定隔年薪資類別的關鍵）
batting_df['service_time'] = (batting_df['Year'] - batting_df['debut_year']).clip(lower=0)
pitching_df['service_time'] = (pitching_df['Year'] - pitching_df['debut_year']).clip(lower=0)

# 分類隔年適用的年資類別（pre-arb / arb / FA）
def classify_for_next_year(service_end_current):
    if np.isnan(service_end_current):
        return 'unknown'
    if service_end_current < 3:
        return 'pre-arb'
    elif service_end_current < 6:
        return 'arb'
    else:
        return 'FA'

batting_df['status_next_year'] = batting_df['service_time'].apply(classify_for_next_year)
pitching_df['status_next_year'] = pitching_df['service_time'].apply(classify_for_next_year)

# 做 one-hot encoding
batting_df = pd.get_dummies(
    batting_df,
    columns=['status_next_year'],
    prefix='status',          # 產生的欄位會變成 status_pre-arb, status_arb, status_FA
    drop_first=False          
)

pitching_df = pd.get_dummies(
    pitching_df,
    columns=['status_next_year'],
    prefix='status',          # 產生的欄位會變成 status_pre-arb, status_arb, status_FA
    drop_first=False          
)

# 加入 lag_1_log_salary
batting_df['lag_1_log_salary'] = batting_df.groupby('name_clean')['Salary'].shift(1).pipe(np.log1p)
batting_df['lag_1_log_salary'] = batting_df['lag_1_log_salary'].fillna(0)



print(batting_df.head())
print(pitching_df.head())
print(batting_df[batting_df.name_clean=='mookiebetts'].sort_values('Year')[['name_clean', 'Year', 'Salary', 'next_year_salary', 'WAR', 'L-WAR']])
# Out:
#     IDfg  Season          Name Team  Age    G   AB   PA    H   1B  ...  \
# 0  15640    2022   Aaron Judge  NYY   30  157  570  696  177   87  ...
# 1  13611    2018  Mookie Betts  BOS   25  136  520  614  180   96  ...
# 2  10155    2013    Mike Trout  LAA   21  157  589  716  190  115  ...
# 3  10155    2018    Mike Trout  LAA   26  140  471  608  147   80  ...
# 4  11579    2015  Bryce Harper  WSN   22  153  521  654  172   91  ...
#
#        Name_sal  next_year_salary  next_year_log_salary  debut_year  \
# 0   Aaron Judge        40000000.0             17.504390      2016.0
# 1  Mookie Betts        20100000.0             16.816230      2014.0
# 2    Mike Trout         1000000.0             13.815512      2011.0
# 3    Mike Trout        36000000.0             17.399030      2011.0
# 4  Bryce Harper         5000000.0             15.424949      2012.0
#
#    service_time  status_FA  status_arb  status_pre-arb  status_unknown  \
# 0           6.0       True       False           False           False
# 1           4.0      False        True           False           False
# 2           2.0      False       False            True           False
# 3           7.0       True       False           False           False
# 4           3.0      False        True           False           False
#
#    lag_1_log_salary
# 0          0.000000
# 1          0.000000
# 2          0.000000
# 3         13.142168
# 4          0.000000
#
# [5 rows x 334 columns]
#     IDfg  Season             Name Team  Age   W  L  WAR   ERA   G  ...  \
# 0  10954    2018     Jacob deGrom  NYM   30  10  9  9.0  1.70  32  ...
# 1   2036    2015  Clayton Kershaw  LAD   27  16  7  8.6  2.13  33  ...
# 2   2036    2014  Clayton Kershaw  LAD   26  21  3  7.9  1.77  27  ...
# 3  10603    2017       Chris Sale  BOS   28  17  8  7.6  2.90  32  ...
# 4  13125    2019      Gerrit Cole  HOU   28  20  5  7.5  2.50  33  ...
#
#        Salary         Name_sal  next_year_salary  next_year_log_salary  \
# 0   7400000.0     Jacob deGrom        12000000.0             16.300417
# 1  32571000.0  Clayton Kershaw        33000000.0             17.312018
# 2   4000000.0  Clayton Kershaw        32571000.0             17.298933
# 3  12000000.0       Chris Sale        12515000.0             16.342439
# 4  13500000.0      Gerrit Cole        13333333.0             16.405778
#
#    debut_year  service_time  status_FA  status_arb  status_pre-arb  \
# 0      2014.0           4.0      False        True           False
# 1      2008.0           7.0       True       False           False
# 2      2008.0           6.0       True       False           False
# 3      2010.0           7.0       True       False           False
# 4      2013.0           6.0       True       False           False
#
#    status_unknown
# 0           False
# 1           False
# 2           False
# 3           False
# 4           False
#
# [5 rows x 406 columns]
#       name_clean    Year      Salary  next_year_salary   WAR  L-WAR
# 232  mookiebetts  2015.0    514500.0          566000.0   4.8    4.8
# 27   mookiebetts  2016.0    566000.0          950000.0   7.4    8.1
# 262  mookiebetts  2017.0    950000.0        10500000.0   4.6    5.2
# 1    mookiebetts  2018.0  10500000.0        20100000.0  10.2   10.4
# 125  mookiebetts  2019.0  20100000.0        27000000.0   5.8    6.3
# 733  mookiebetts  2020.0  27000000.0        14500000.0   2.7    2.8
# 406  mookiebetts  2021.0  14500000.0        14500000.0   3.9    3.9
# 107  mookiebetts  2022.0  14500000.0        17000000.0   6.0    6.4
# 21   mookiebetts  2023.0  17000000.0        22000000.0   7.6    8.2

# %% [markdown]
# # 特徵工程

# %%
import pandas as pd
import numpy as np
from sklearn.ensemble import RandomForestRegressor
from sklearn.feature_selection import SelectKBest, f_regression
from sklearn.model_selection import cross_val_score
import warnings
warnings.filterwarnings('ignore')

# 打者特徵

# 1. 定義打者「當季核心特徵」
batter_core_features = [
    'Age',                              # 年齡
    'service_time',                     # 當季結束時年資
    'G', 'PA', 'AB',                    # 出賽量
    'R', 'H', 'HR', 'RBI', 'SB',        # 基本產出
    'BB', 'SO',
    'AVG', 'OBP', 'SLG', 'OPS',         # 傳統打擊三圍
    'ISO', 'BABIP',
    'wOBA', 'wRC+', 'WAR', 'L-WAR',     # 進階綜合指標
    'BB%', 'K%', 'BB/K',
    'Barrel%', 'HardHit%', 'EV', 'maxEV', # Statcast 力量
    'xBA', 'xSLG', 'xwOBA'              # Statcast 預期
]

# 加入 lag_1_log_salary

batter_core_features.append('lag_1_log_salary')


# 加入 status的one-hot 欄位
status_columns = [col for col in batting_df.columns if col.startswith('status_')]
batter_core_features += status_columns

# 只保留實際存在的欄位
batter_features = [f for f in batter_core_features if f in batting_df.columns]
batting_df = batting_df[batting_df['next_year_log_salary'].notna()].copy()

X_batter = batting_df[batter_features].fillna(0)
y_batter = batting_df['next_year_log_salary']

print(f"打者初始特徵數：{len(batter_features)}")

# 2. 使用 RandomForest 計算重要度
rf = RandomForestRegressor(n_estimators=120, random_state=42, n_jobs=-1)
rf.fit(X_batter, y_batter)

importances = pd.Series(rf.feature_importances_, index=batter_features)
importances = importances.sort_values(ascending=False)

print("\n打者當季特徵重要度 Top 30：")
print(importances)



# 畫熱圖檢查共線性

# 只看數值型特徵（排除 one-hot）
numeric_features = [f for f in batter_features if f not in 
                    [col for col in batting_df.columns if col.startswith(('status_'))]]

corr_matrix = batting_df[numeric_features + ['next_year_log_salary']].corr()

# 畫熱圖
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(18, 16))
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm', fmt='.2f', linewidths=0.5)
plt.title("特徵與目標的相關性熱圖")
plt.show()

# 手動刪除高共線性特徵（刪至19個 刪除 L-WAR, wOBA, AB, H, BB%, G）
# b_final = [
#     'service_time', 'wRC+', 'Age', 'status_pre-arb', 'PA', 'WAR',
#     'RBI', 'R', 'BABIP', 'SB', 'SO', 'K%', 'BB', 'BB/K',
#     'HR', 'xBA', 'maxEV', 'HardHit%', 'SLG'   
# ]

# 加入 lag_1_log_salary
# b_final.append('lag_1_log_salary')

# 再精簡特徵(刪至13 刪除 SLG, R, RBI, BB/K, SB, SO)(BB%取代BB)
b_final = [
    'service_time', 'wRC+', 'Age', 'status_pre-arb', 'PA', 'WAR',
    'BABIP', 'K%', 'BB%', 
    'HR', 'xBA', 'maxEV', 'HardHit%'  
]



# 1. 定義投手「當季核心特徵」
pitcher_core_features = [
    'Age',
    'service_time',
    'G', 'GS', 'IP',                    # 出賽量與先發數
    'ERA', 'FIP', 'xFIP', 'SIERA',      # 核心 ERA 相關指標
    'W', 'SV',
    'WHIP', 'K/9', 'BB/9', 'K-BB%',     # 控球與三振
    'HR/9',
    'K%', 'BB%',
    'BABIP', 'LOB%',                    # 運氣與殘壘率
    'ERA-', 'FIP-',                     # 聯盟調整版
    'WAR', 'L-WAR',                     # 綜合貢獻
    'EV', 'HardHit%', 'Barrel%', 'xwOBA'# Statcast
]

# 加入 status的one-hot 欄位
status_columns = [col for col in pitching_df.columns if col.startswith('status_')]
pitcher_core_features += status_columns

# 只保留存在的欄位
pitcher_features = [f for f in pitcher_core_features if f in pitching_df.columns]
pitching_df = pitching_df[pitching_df['next_year_log_salary'].notna()].copy()

X_pitcher = pitching_df[pitcher_features].fillna(0)
y_pitcher = pitching_df['next_year_log_salary']

print(f"投手初始特徵數：{len(pitcher_features)}")

# 2. RandomForest 重要度
rf_p = RandomForestRegressor(n_estimators=120, random_state=42, n_jobs=-1)
rf_p.fit(X_pitcher, y_pitcher)

importances_p = pd.Series(rf_p.feature_importances_, index=pitcher_features)
importances_p = importances_p.sort_values(ascending=False)

print("\n投手當季特徵重要度 Top 25：")
print(importances_p.head(25))


# 畫熱圖檢查共線性

# 只看數值型特徵（排除 one-hot）
p_numeric_features = [f for f in pitcher_features if f not in 
                    [col for col in pitching_df.columns if col.startswith(('status_'))]]

p_corr_matrix = pitching_df[p_numeric_features + ['next_year_log_salary']].corr()

# 畫熱圖
plt.figure(figsize=(18, 16))
sns.heatmap(p_corr_matrix, annot=True, cmap='coolwarm', fmt='.2f', linewidths=0.5)
plt.title("特徵與目標的相關性熱圖")
plt.show()

# 手動刪除高共線性特徵（刪了 G, FIP, xFIP, BB%, K%, EV, status_arb, FIP-）
p_final = [
    'service_time', 'status_pre-arb', 'Age', 'SIERA', 'IP', 'WAR','BABIP',
    'BB/9', 'K/9', 'HardHit%','LOB%', 'Barrel%', 'K-BB%', 'WHIP', 'W', 
    'HR/9', 'ERA' 
    
]
# Out:
# 打者初始特徵數：37
#
# 打者當季特徵重要度 Top 30：
# service_time        0.378475
# lag_1_log_salary    0.053844
# Age                 0.035177
# wRC+                0.034111
# status_pre-arb      0.027837
# L-WAR               0.026107
# PA                  0.023157
# WAR                 0.022305
# RBI                 0.022117
# R                   0.020281
# BABIP               0.019569
# wOBA                0.017083
# xBA                 0.016873
# K%                  0.016328
# SO                  0.016308
# SB                  0.016269
# BB%                 0.015593
# maxEV               0.015323
# status_arb          0.014961
# SLG                 0.014846
# HardHit%            0.014658
# BB                  0.014389
# AVG                 0.014346
# HR                  0.013788
# H                   0.013633
# BB/K                0.013455
# ISO                 0.013048
# AB                  0.012444
# xSLG                0.012342
# Barrel%             0.012058
# G                   0.011812
# OBP                 0.011690
# OPS                 0.011525
# xwOBA               0.010015
# EV                  0.009299
# status_FA           0.004882
# status_unknown      0.000053
# dtype: float64
# 投手初始特徵數：30
#
# 投手當季特徵重要度 Top 25：
# service_time      0.239263
# status_pre-arb    0.186315
# Age               0.125679
# SIERA             0.063104
# xFIP              0.036805
# IP                0.024586
# WAR               0.020819
# BABIP             0.020626
# FIP               0.019982
# G                 0.018898
# BB/9              0.017489
# K/9               0.016651
# BB%               0.015939
# HardHit%          0.015689
# LOB%              0.015347
# Barrel%           0.015295
# K-BB%             0.015074
# K%                0.014847
# EV                0.014778
# WHIP              0.014666
# W                 0.013969
# HR/9              0.013241
# status_arb        0.012784
# ERA               0.012561
# FIP-              0.011414
# dtype: float64

# %% [markdown]
# # 訓練模型
#
# ## 打者模型實驗記錄
#
# ### batter v1 - Baseline XGBoost
# - 參數：n_estimators=300, lr=0.03, max_depth=5
# - 訓練 R²: 0.9137
# - 測試 R²: 0.2871
# - 問題：嚴重過擬合
#
# ### batter v2 - 加強正則化
# - 參數：n_estimators=600, lr=0.008, max_depth=4, reg_lambda=3
# - 訓練 R²: 0.7186
# - 測試 R²: 0.2933
# - 改善：差距從 0.626 → 0.425
#
# ### batter v3 - 繼續加強
# - 參數：n_estimators=800, lr=0.005, max_depth=3, reg_lambda=15.0
# - 訓練 R²: 0.5858
# - 測試 R²: 0.2820
# - 改善：過擬合繼續被壓制（差距從 0.425 → 0.304）但測試 R² 不升反降（0.2933 → 0.2820）underfitting 開始出現
#
# ### batter v4 - 參數折衷版
# - n_estimators=700, learning_rate=0.007, max_depth=4
# - reg_lambda=12.0, reg_alpha=0.5, min_child_weight=6
# - 訓練 R²: 0.6826 / RMSE: 0.7189
# - 測試 R²: 0.2943 / RMSE: 1.0684
# - 結論：目前最佳平衡點，測試表現最高
#
# ### batter v5 - 加入 lag_1_log_salary
# - 新增特徵：lag_1_log_salary（前一年薪資 log，填 0 處理新人）
# - 參數：延續 v4 折衷版
# - 訓練 R²: 0.7100 / RMSE: 0.6872
# - 測試 R²: 0.2568 / RMSE: 1.0965
# - 結論：測試表現下降，可能因 lag_1 與 service_time/status 高共線，造成過度依賴慣性
# - 下一步：移除或降權 lag_1，或先移除部分年資 one-hot 再試
#
# ### batter v6 - 移除 lag_1_log_salary
# - 基於 v4 參數
# - 訓練 R²: 0.6826 / RMSE: 0.7189
# - 測試 R²: 0.2943 / RMSE: 1.0684
# - 結論：與 v4 完全相同，證明 lag_1_log_salary 在此階段帶來負向影響（可能與年資共線或過度依賴慣性）
# - 決定：暫不使用 lag_1_log_salary，鎖定 v4 作為基準
#
# ### batter v7 - 精簡到 13 個特徵
# - 特徵：刪除 SB、SO、BB等
# - 參數：延續 v4 折衷版
# - 訓練 R²: 0.6680 / RMSE: 0.7352
# - 測試 R²: 0.2974 / RMSE: 1.0660
# - 結論：測試表現微升 0.0031，過擬合差距縮小至 0.3706，目前最佳版本
# - 決定：鎖定這 13 個特徵作為打者最終模型
#
# ### 模型實驗結果比較表
#
# | 版本 | 主要調整                          | 訓練 R² | 訓練 RMSE | 測試 R² | 測試 RMSE | 訓練-測試差距 | 評論 |
# |------|-----------------------------------|---------|-----------|---------|-----------|----------------|------|
# | v1   | Baseline XGBoost                  | 0.9137  | 0.3749    | 0.2871  | 1.0738    | 0.6266         | 嚴重過擬合 |
# | v2   | 正則化 v2 (reg_lambda=10)         | 0.7186  | 0.6769    | 0.2933  | 1.0692    | 0.4253         | 過擬合減輕 |
# | v3   | 正則化 v3 (更強)                  | 0.5858  | 0.8212    | 0.2820  | 1.0777    | 0.3038         | 過正則化 |
# | v4   | 折衷版 (reg_lambda=12, depth=4)   | 0.6826  | 0.7189    | 0.2943  | 1.0684    | 0.3883         | 之前最佳 |
# | v5   | v4 + lag_1_log_salary             | 0.7100  | 0.6872    | 0.2568  | 1.0965    | 0.4532         | 測試下降 |
# | v6   | 移除 lag_1，回到 v4               | 0.6826  | 0.7189    | 0.2943  | 1.0684    | 0.3883         | 回到 v4 |
# | v7   | 精簡到 13 個特徵                  | 0.6680  | 0.7352    | 0.2974  | 1.0660    | 0.3706         | 目前最佳 |

# %%
import pandas as pd
import numpy as np
from xgboost import XGBRegressor
from sklearn.metrics import r2_score, mean_squared_error
from xgboost.callback import EarlyStopping


# 共用評估函數
def evaluate_model(y_true, y_pred, title=""):
    r2 = r2_score(y_true, y_pred)
    rmse = np.sqrt(mean_squared_error(y_true, y_pred))
    print(f"{title}")
    print(f"  R²    : {r2:.4f}")
    print(f"  RMSE  : {rmse:.4f}")
    return r2, rmse

# 畫預測 vs 真實值散點圖
def plot_predictions(y_true, y_pred, title=""):
    plt.figure(figsize=(8, 6))
    plt.scatter(y_true, y_pred, alpha=0.6)
    plt.plot([y_true.min(), y_true.max()], [y_true.min(), y_true.max()], 'r--', lw=2)
    plt.xlabel("True next_year_log_salary")
    plt.ylabel("Predicted")
    plt.title(title)
    plt.grid(True, alpha=0.3)
    plt.show()

# 打者最終特徵 (19)
# b_final = [
#     'service_time', 'wRC+', 'Age', 'status_pre-arb', 'PA', 'WAR',
#     'RBI', 'R', 'BABIP', 'SB', 'SO', 'K%', 'BB', 'BB/K',
#     'HR', 'xBA', 'maxEV', 'HardHit%', 'SLG'   
# ]

# 加入 lag_1_log_salary
# b_final.append('lag_1_log_salary')

# 精簡版 (13)
b_final = [
    'service_time', 'wRC+', 'Age', 'status_pre-arb', 'PA', 'WAR',
    'BABIP', 'K%', 'BB%', 
    'HR', 'xBA', 'maxEV', 'HardHit%'  
]



# 準備資料
X_batter = batting_df[b_final].fillna(0)
y_batter = batting_df['next_year_log_salary']

# 時間序列切分（建議 2021 年以前訓練，之後測試）
train_mask = batting_df['Year'] <= 2021
test_mask  = batting_df['Year'] > 2021

X_train_b = X_batter[train_mask]
y_train_b = y_batter[train_mask]
X_test_b  = X_batter[test_mask]
y_test_b  = y_batter[test_mask]

print(f"打者訓練樣本：{len(X_train_b)}，測試樣本：{len(X_test_b)}")

# batter v1 XGBoost 模型
# xgb_batter = XGBRegressor(
#     n_estimators=300,
#     learning_rate=0.03,
#     max_depth=5,
#     subsample=0.8,
#     colsample_bytree=0.8,
#     random_state=42,
#     n_jobs=-1,
#     objective='reg:squarederror'
# )


# batter v2 加強正則化的版本 
# xgb_batter = XGBRegressor(
#     n_estimators=600,
#     learning_rate=0.008,
#     max_depth=4,
#     min_child_weight=3,
#     gamma=0.05,
#     subsample=0.75,
#     colsample_bytree=0.75,
#     reg_lambda=3.0,          # 加 L2 正則
#     reg_alpha=0.5,
#     random_state=42,
#     n_jobs=-1
# )

# batter v3 繼續加強
# xgb_batter = XGBRegressor(
#     n_estimators=800,
#     learning_rate=0.005,
#     max_depth=3,                # 再降低
#     min_child_weight=10,
#     gamma=0.3,
#     subsample=0.6,
#     colsample_bytree=0.6,
#     reg_lambda=15.0,            # 再提高
#     reg_alpha=2.0,
#     random_state=42,
#     n_jobs=-1
# )

# batter v4 參數折衷
xgb_batter = XGBRegressor(
    n_estimators=700,
    learning_rate=0.007,          # 介於 0.005 和 0.008
    max_depth=4,                  # 回到 4，但不回 5
    min_child_weight=6,           # 介於 5~10
    gamma=0.1,
    subsample=0.7,
    colsample_bytree=0.7,
    reg_lambda=12.0,              # 介於 10 和 15
    reg_alpha=0.5,
    random_state=42,
    n_jobs=-1
)



# 定義 early stopping
early_stop = EarlyStopping(
    rounds=60,                    # 連續 60 次沒改善就停
    metric_name='rmse',
    data_name='validation_0',     # eval_set 第一個是 validation_0
    save_best=True                # 回傳最佳模型
)

xgb_batter.fit(
    X_train_b, y_train_b,
    eval_set=[(X_test_b, y_test_b)],  # 一定要加這個
    callbacks=[early_stop],
    verbose=False
)


# xgb_batter.fit(
#     X_train_b, y_train_b,
#     verbose=False
# )


# 預測與評估
y_pred_train_b = xgb_batter.predict(X_train_b)
y_pred_test_b  = xgb_batter.predict(X_test_b)

evaluate_model(y_train_b, y_pred_train_b, "打者 - 訓練集表現")
evaluate_model(y_test_b,  y_pred_test_b,  "打者 - 測試集表現")

# 畫圖
plot_predictions(y_test_b, y_pred_test_b, "打者 - 測試集預測 vs 真實 (log salary)")

# 特徵重要度（XGBoost 版本）
from xgboost import plot_importance
plot_importance(xgb_batter, max_num_features=20)
plt.show()
# Out:
# 打者訓練樣本：1180，測試樣本：219
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[141], line 130
#     122 # 定義 early stopping
#     123 early_stop = EarlyStopping(
#     124     rounds=60,                    # 連續 60 次沒改善就停
#     125     metric_name='rmse',
#     126     data_name='validation_0',     # eval_set 第一個是 validation_0
#     127     save_best=True                # 回傳最佳模型
#     128 )
# --> 130 xgb_batter.fit(
#     131     X_train_b, y_train_b,
#     132     eval_set=[(X_test_b, y_test_b)],  # 一定要加這個
#     133     callbacks=[early_stop],
#     134     verbose=False
#     135 )
#     138 # xgb_batter.fit(
#     139 #     X_train_b, y_train_b,
#     140 #     verbose=False
#    (...)    143
#     144 # 預測與評估
#     145 y_pred_train_b = xgb_batter.predict(X_train_b)
#
# File ~\anaconda3\Lib\site-packages\xgboost\core.py:726, in require_keyword_args.<locals>.throw_if.<locals>.inner_f(*args, **kwargs)
#     724 for k, arg in zip(sig.parameters, args):
#     725     kwargs[k] = arg
# --> 726 return func(**kwargs)
#
# TypeError: XGBModel.fit() got an unexpected keyword argument 'callbacks'

# %% [markdown]
# ## 投手模型實驗記錄

# %%
# 投手最終特徵 (17)
p_final = [
    'service_time', 'status_pre-arb', 'Age', 'SIERA', 'IP', 'WAR','BABIP',
    'BB/9', 'K/9', 'HardHit%','LOB%', 'Barrel%', 'K-BB%', 'WHIP', 'W', 
    'HR/9', 'ERA'    
]
# Out:
# ['IDfg', 'Season', 'Name', 'Team', 'Age', 'G', 'AB', 'PA', 'H', '1B', '2B', '3B', 'HR', 'R', 'RBI', 'BB', 'IBB', 'SO', 'HBP', 'SF', 'SH', 'GDP', 'SB', 'CS', 'AVG', 'GB', 'FB', 'LD', 'IFFB', 'Pitches', 'Balls', 'Strikes', 'IFH', 'BU', 'BUH', 'BB%', 'K%', 'BB/K', 'OBP', 'SLG', 'OPS', 'ISO', 'BABIP', 'GB/FB', 'LD%', 'GB%', 'FB%', 'IFFB%', 'HR/FB', 'IFH%', 'BUH%', 'wOBA', 'wRAA', 'wRC', 'Bat', 'Fld', 'Rep', 'Pos', 'RAR', 'WAR', 'Dol', 'Spd', 'wRC+', 'WPA', '-WPA', '+WPA', 'RE24', 'REW', 'pLI', 'phLI', 'PH', 'WPA/LI', 'Clutch', 'FB% (Pitch)', 'FBv', 'SL%', 'SLv', 'CT%', 'CTv', 'CB%', 'CBv', 'CH%', 'CHv', 'SF%', 'SFv', 'KN%', 'KNv', 'XX%', 'PO%', 'wFB', 'wSL', 'wCT', 'wCB', 'wCH', 'wSF', 'wKN', 'wFB/C', 'wSL/C', 'wCT/C', 'wCB/C', 'wCH/C', 'wSF/C', 'wKN/C', 'O-Swing%', 'Z-Swing%', 'Swing%', 'O-Contact%', 'Z-Contact%', 'Contact%', 'Zone%', 'F-Strike%', 'SwStr%', 'BsR', 'FA% (sc)', 'FT% (sc)', 'FC% (sc)', 'FS% (sc)', 'FO% (sc)', 'SI% (sc)', 'SL% (sc)', 'CU% (sc)', 'KC% (sc)', 'EP% (sc)', 'CH% (sc)', 'SC% (sc)', 'KN% (sc)', 'UN% (sc)', 'vFA (sc)', 'vFT (sc)', 'vFC (sc)', 'vFS (sc)', 'vFO (sc)', 'vSI (sc)', 'vSL (sc)', 'vCU (sc)', 'vKC (sc)', 'vEP (sc)', 'vCH (sc)', 'vSC (sc)', 'vKN (sc)', 'FA-X (sc)', 'FT-X (sc)', 'FC-X (sc)', 'FS-X (sc)', 'FO-X (sc)', 'SI-X (sc)', 'SL-X (sc)', 'CU-X (sc)', 'KC-X (sc)', 'EP-X (sc)', 'CH-X (sc)', 'SC-X (sc)', 'KN-X (sc)', 'FA-Z (sc)', 'FT-Z (sc)', 'FC-Z (sc)', 'FS-Z (sc)', 'FO-Z (sc)', 'SI-Z (sc)', 'SL-Z (sc)', 'CU-Z (sc)', 'KC-Z (sc)', 'EP-Z (sc)', 'CH-Z (sc)', 'SC-Z (sc)', 'KN-Z (sc)', 'wFA (sc)', 'wFT (sc)', 'wFC (sc)', 'wFS (sc)', 'wFO (sc)', 'wSI (sc)', 'wSL (sc)', 'wCU (sc)', 'wKC (sc)', 'wEP (sc)', 'wCH (sc)', 'wSC (sc)', 'wKN (sc)', 'wFA/C (sc)', 'wFT/C (sc)', 'wFC/C (sc)', 'wFS/C (sc)', 'wFO/C (sc)', 'wSI/C (sc)', 'wSL/C (sc)', 'wCU/C (sc)', 'wKC/C (sc)', 'wEP/C (sc)', 'wCH/C (sc)', 'wSC/C (sc)', 'wKN/C (sc)', 'O-Swing% (sc)', 'Z-Swing% (sc)', 'Swing% (sc)', 'O-Contact% (sc)', 'Z-Contact% (sc)', 'Contact% (sc)', 'Zone% (sc)', 'Pace', 'Def', 'wSB', 'UBR', 'Age Rng', 'Off', 'Lg', 'wGDP', 'Pull%', 'Cent%', 'Oppo%', 'Soft%', 'Med%', 'Hard%', 'TTO%', 'CH% (pi)', 'CS% (pi)', 'CU% (pi)', 'FA% (pi)', 'FC% (pi)', 'FS% (pi)', 'KN% (pi)', 'SB% (pi)', 'SI% (pi)', 'SL% (pi)', 'XX% (pi)', 'vCH (pi)', 'vCS (pi)', 'vCU (pi)', 'vFA (pi)', 'vFC (pi)', 'vFS (pi)', 'vKN (pi)', 'vSB (pi)', 'vSI (pi)', 'vSL (pi)', 'vXX (pi)', 'CH-X (pi)', 'CS-X (pi)', 'CU-X (pi)', 'FA-X (pi)', 'FC-X (pi)', 'FS-X (pi)', 'KN-X (pi)', 'SB-X (pi)', 'SI-X (pi)', 'SL-X (pi)', 'XX-X (pi)', 'CH-Z (pi)', 'CS-Z (pi)', 'CU-Z (pi)', 'FA-Z (pi)', 'FC-Z (pi)', 'FS-Z (pi)', 'KN-Z (pi)', 'SB-Z (pi)', 'SI-Z (pi)', 'SL-Z (pi)', 'XX-Z (pi)', 'wCH (pi)', 'wCS (pi)', 'wCU (pi)', 'wFA (pi)', 'wFC (pi)', 'wFS (pi)', 'wKN (pi)', 'wSB (pi)', 'wSI (pi)', 'wSL (pi)', 'wXX (pi)', 'wCH/C (pi)', 'wCS/C (pi)', 'wCU/C (pi)', 'wFA/C (pi)', 'wFC/C (pi)', 'wFS/C (pi)', 'wKN/C (pi)', 'wSB/C (pi)', 'wSI/C (pi)', 'wSL/C (pi)', 'wXX/C (pi)', 'O-Swing% (pi)', 'Z-Swing% (pi)', 'Swing% (pi)', 'O-Contact% (pi)', 'Z-Contact% (pi)', 'Contact% (pi)', 'Zone% (pi)', 'Pace (pi)', 'FRM', 'AVG+', 'BB%+', 'K%+', 'OBP+', 'SLG+', 'ISO+', 'BABIP+', 'LD+%', 'GB%+', 'FB%+', 'HR/FB%+', 'Pull%+', 'Cent%+', 'Oppo%+', 'Soft%+', 'Med%+', 'Hard%+', 'EV', 'LA', 'Barrels', 'Barrel%', 'maxEV', 'HardHit', 'HardHit%', 'Events', 'CStr%', 'CSW%', 'xBA', 'xSLG', 'xwOBA', 'L-WAR', 'name_clean']

# %%
print(salary_df.head())
# Out:
#    Year Team           Name      Salary    name_clean
# 0  2011  ARI  Kelly Johnson  $5,850,000  kellyjohnson
# 1  2011  ARI   Joe Saunders  $5,500,000   joesaunders
# 2  2011  ARI    Chris Young  $5,200,000    chrisyoung
# 3  2011  ARI   Stephen Drew  $4,650,000   stephendrew
# 4  2011  ARI   Justin Upton  $4,458,333   justinupton

# %%
print(pitching_df.columns.tolist())
# Out:
# ['IDfg', 'Season', 'Name', 'Team', 'Age', 'W', 'L', 'WAR', 'ERA', 'G', 'GS', 'CG', 'ShO', 'SV', 'BS', 'IP', 'TBF', 'H', 'R', 'ER', 'HR', 'BB', 'IBB', 'HBP', 'WP', 'BK', 'SO', 'GB', 'FB', 'LD', 'IFFB', 'Balls', 'Strikes', 'Pitches', 'RS', 'IFH', 'BU', 'BUH', 'K/9', 'BB/9', 'K/BB', 'H/9', 'HR/9', 'AVG', 'WHIP', 'BABIP', 'LOB%', 'FIP', 'GB/FB', 'LD%', 'GB%', 'FB%', 'IFFB%', 'HR/FB', 'IFH%', 'BUH%', 'Starting', 'Start-IP', 'Relieving', 'Relief-IP', 'RAR', 'Dollars', 'tERA', 'xFIP', 'WPA', '-WPA', '+WPA', 'RE24', 'REW', 'pLI', 'inLI', 'gmLI', 'exLI', 'Pulls', 'WPA/LI', 'Clutch', 'FB% 2', 'FBv', 'SL%', 'SLv', 'CT%', 'CTv', 'CB%', 'CBv', 'CH%', 'CHv', 'SF%', 'SFv', 'KN%', 'KNv', 'XX%', 'PO%', 'wFB', 'wSL', 'wCT', 'wCB', 'wCH', 'wSF', 'wKN', 'wFB/C', 'wSL/C', 'wCT/C', 'wCB/C', 'wCH/C', 'wSF/C', 'wKN/C', 'O-Swing%', 'Z-Swing%', 'Swing%', 'O-Contact%', 'Z-Contact%', 'Contact%', 'Zone%', 'F-Strike%', 'SwStr%', 'HLD', 'SD', 'MD', 'ERA-', 'FIP-', 'xFIP-', 'K%', 'BB%', 'SIERA', 'RS/9', 'E-F', 'FA% (sc)', 'FT% (sc)', 'FC% (sc)', 'FS% (sc)', 'FO% (sc)', 'SI% (sc)', 'SL% (sc)', 'CU% (sc)', 'KC% (sc)', 'EP% (sc)', 'CH% (sc)', 'SC% (sc)', 'KN% (sc)', 'UN% (sc)', 'vFA (sc)', 'vFT (sc)', 'vFC (sc)', 'vFS (sc)', 'vFO (sc)', 'vSI (sc)', 'vSL (sc)', 'vCU (sc)', 'vKC (sc)', 'vEP (sc)', 'vCH (sc)', 'vSC (sc)', 'vKN (sc)', 'FA-X (sc)', 'FT-X (sc)', 'FC-X (sc)', 'FS-X (sc)', 'FO-X (sc)', 'SI-X (sc)', 'SL-X (sc)', 'CU-X (sc)', 'KC-X (sc)', 'EP-X (sc)', 'CH-X (sc)', 'SC-X (sc)', 'KN-X (sc)', 'FA-Z (sc)', 'FT-Z (sc)', 'FC-Z (sc)', 'FS-Z (sc)', 'FO-Z (sc)', 'SI-Z (sc)', 'SL-Z (sc)', 'CU-Z (sc)', 'KC-Z (sc)', 'EP-Z (sc)', 'CH-Z (sc)', 'SC-Z (sc)', 'KN-Z (sc)', 'wFA (sc)', 'wFT (sc)', 'wFC (sc)', 'wFS (sc)', 'wFO (sc)', 'wSI (sc)', 'wSL (sc)', 'wCU (sc)', 'wKC (sc)', 'wEP (sc)', 'wCH (sc)', 'wSC (sc)', 'wKN (sc)', 'wFA/C (sc)', 'wFT/C (sc)', 'wFC/C (sc)', 'wFS/C (sc)', 'wFO/C (sc)', 'wSI/C (sc)', 'wSL/C (sc)', 'wCU/C (sc)', 'wKC/C (sc)', 'wEP/C (sc)', 'wCH/C (sc)', 'wSC/C (sc)', 'wKN/C (sc)', 'O-Swing% (sc)', 'Z-Swing% (sc)', 'Swing% (sc)', 'O-Contact% (sc)', 'Z-Contact% (sc)', 'Contact% (sc)', 'Zone% (sc)', 'Pace', 'RA9-WAR', 'BIP-Wins', 'LOB-Wins', 'FDP-Wins', 'Age Rng', 'K-BB%', 'Pull%', 'Cent%', 'Oppo%', 'Soft%', 'Med%', 'Hard%', 'kwERA', 'TTO%', 'CH% (pi)', 'CS% (pi)', 'CU% (pi)', 'FA% (pi)', 'FC% (pi)', 'FS% (pi)', 'KN% (pi)', 'SB% (pi)', 'SI% (pi)', 'SL% (pi)', 'XX% (pi)', 'vCH (pi)', 'vCS (pi)', 'vCU (pi)', 'vFA (pi)', 'vFC (pi)', 'vFS (pi)', 'vKN (pi)', 'vSB (pi)', 'vSI (pi)', 'vSL (pi)', 'vXX (pi)', 'CH-X (pi)', 'CS-X (pi)', 'CU-X (pi)', 'FA-X (pi)', 'FC-X (pi)', 'FS-X (pi)', 'KN-X (pi)', 'SB-X (pi)', 'SI-X (pi)', 'SL-X (pi)', 'XX-X (pi)', 'CH-Z (pi)', 'CS-Z (pi)', 'CU-Z (pi)', 'FA-Z (pi)', 'FC-Z (pi)', 'FS-Z (pi)', 'KN-Z (pi)', 'SB-Z (pi)', 'SI-Z (pi)', 'SL-Z (pi)', 'XX-Z (pi)', 'wCH (pi)', 'wCS (pi)', 'wCU (pi)', 'wFA (pi)', 'wFC (pi)', 'wFS (pi)', 'wKN (pi)', 'wSB (pi)', 'wSI (pi)', 'wSL (pi)', 'wXX (pi)', 'wCH/C (pi)', 'wCS/C (pi)', 'wCU/C (pi)', 'wFA/C (pi)', 'wFC/C (pi)', 'wFS/C (pi)', 'wKN/C (pi)', 'wSB/C (pi)', 'wSI/C (pi)', 'wSL/C (pi)', 'wXX/C (pi)', 'O-Swing% (pi)', 'Z-Swing% (pi)', 'Swing% (pi)', 'O-Contact% (pi)', 'Z-Contact% (pi)', 'Contact% (pi)', 'Zone% (pi)', 'Pace (pi)', 'FRM', 'K/9+', 'BB/9+', 'K/BB+', 'H/9+', 'HR/9+', 'AVG+', 'WHIP+', 'BABIP+', 'LOB%+', 'K%+', 'BB%+', 'LD%+', 'GB%+', 'FB%+', 'HR/FB%+', 'Pull%+', 'Cent%+', 'Oppo%+', 'Soft%+', 'Med%+', 'Hard%+', 'EV', 'LA', 'Barrels', 'Barrel%', 'maxEV', 'HardHit', 'HardHit%', 'Events', 'CStr%', 'CSW%', 'xERA', 'botERA', 'botOvr CH', 'botStf CH', 'botCmd CH', 'botOvr CU', 'botStf CU', 'botCmd CU', 'botOvr FA', 'botStf FA', 'botCmd FA', 'botOvr SI', 'botStf SI', 'botCmd SI', 'botOvr SL', 'botStf SL', 'botCmd SL', 'botOvr KC', 'botStf KC', 'botCmd KC', 'botOvr FC', 'botStf FC', 'botCmd FC', 'botOvr FS', 'botStf FS', 'botCmd FS', 'botOvr', 'botStf', 'botCmd', 'botxRV100', 'Stf+ CH', 'Loc+ CH', 'Pit+ CH', 'Stf+ CU', 'Loc+ CU', 'Pit+ CU', 'Stf+ FA', 'Loc+ FA', 'Pit+ FA', 'Stf+ SI', 'Loc+ ...
